# %% [markdown]
# # Environments

# %% [markdown]
# ## Environment 1 - L4137_01_Protease
#
# **List of software included in environment**
#
# | Software |  Version |
# | -------- | -------- |
# | FastQC    |   0.12.1   |
# | miRTrace    |   1.0.1   |

# %% [markdown]
# ## Environment 2 - L4137_01_Protease_cutadapt
#
# **List of software included in environment**
#
# | Software |  Version |
# | -------- | -------- |
# | cutadapt    |   5.2   |

# %% [markdown]
# # Input Data

# %% [markdown]
# - Single-end reads
# - One FASTQ file per sample
# - Single lane (merging multiple lanes not required)

# %%
library(readr)
X01_sample_metadata <- read_csv("/Users/christopherjanschke/GIT/L4137_HBEC_EV_Transcriptomics-Project/01_Protease/results/tables/01_sample_metadata.csv", show_col_types = FALSE)
X01_sample_metadata
# Out:
# Warning message:
# “package ‘readr’ was built under R version 4.5.2”
#    Condition               Treatment Replicate Sequencing ID          File Size
# 1  PBS_03                  Untreated 1         NGS-110-028_S28_R1_001 354M
# 2  PBS_04                  Untreated 2         NGS-110-016_S16_R1_001 374M
# 3  PBS_06                  Untreated 3         NGS-110-007_S7_R1_001  282M
# 4  0_005_ug_mL_Protease_01 Treated   1         NGS-110-029_S29_R1_001 318M
# 5  0_005_ug_mL_Protease_11 Treated   2         NGS-110-017_S17_R1_001 365M
# 6  0_005_ug_mL_Protease_14 Treated   3         NGS-110-011_S11_R1_001 373M
# 7  0_08_ug_mL_Protease_13  Treated   1         NGS-110-012_S12_R1_001 371M
# 8  0_08_ug_mL_Protease_08  Treated   2         NGS-110-025_S25_R1_001 397M
# 9  0_08_ug_mL_Protease_09  Treated   3         NGS-110-006_S6_R1_001  314M
# 10 2_ug_mL_Protease_02     Treated   1         NGS-110-004_S4_R1_001  383M
# 11 2_ug_mL_Protease_05     Treated   2         NGS-110-026_S26_R1_001 405M
# ...

# %% [markdown]
# # Processing Steps

# %% [markdown]
# ## 01. Data Preparation

# %% [markdown]
# ### Final

# %% [markdown]
# ### Test

# %% [markdown]
# #### 1. Input Data

# %% [markdown]
# **Script name:** [].sh
#
# **1. Description**
#
# **2. Software**
# N/A
#
# **3. Software Justification**
# Re-naming files is a simple in-built Linux capability - no specialist software required.
#
# **4. Results**
# Files named according to a standardised format to be used as input data for downstream scripts.
#
# **5. Notes**
# - Takes in file paths, re-names according to convention then saves them in `raw_data`; .csv containing metadata for traceability is produced.
# - Requires single-end read data
# - Wildcards (e.g., `*`, `?`) required if files from multiple lanes exist. The script will concatenate multiple files into one merged file.
#
# **Inputs Files**
# | Name                           | Extension | File Size | Description                                                                                                                |
# | ------------------------------ | --------- | --------- | -------------------------------------------------------------------------------------------------------------------------- |
# | `[]` | .fastq.gz | `[]`  | Gzipped FASTQ file containing [RNA?] |

# %% [markdown]
# ## 02. Quality Control

# %% [markdown]
# ### Final

# %% [markdown]
# ### Test

# %% [markdown]
# #### 1. FastQC

# %% [markdown]
# **Script name:** [].sh
#
# **1. Description**
# Quality control metrics assessed:
# - Basic Statistics
# - Per base sequence quality
# - Per tile sequence quality
# - Per sequence quality scores
# - Per base sequence content
# - Per sequence GC content
# - Per base N content
# - Sequence Length Distribution
# - Sequence Duplication Levels
# - Overrepresented sequences
# - Adapter Content
#
# **2. Software**
# [FastQC](https://github.com/s-andrews/FastQC) v0.12.1
#
# **3. Justification**
# FastQC is a well-established and reliable quality control software used in multi-omics analyses.
#
# **4. Results**
# []
#
# **5. Notes**
# []
#
# **Inputs Files**
# | Name                           | Extension | File Size | Description                                                                                                                |
# | ------------------------------ | --------- | --------- | -------------------------------------------------------------------------------------------------------------------------- |
# | `[]` | .fastq.gz | `[]`  | Gzipped FASTQ file containing [RNA?] |

# %% [markdown]
# #### 1. miRTrace

# %% [markdown]
# **Script name:** [].sh
#
# **1. Description**
#
# **2. Software**
# [mirTRace](https://github.com/friedlanderlab/mirtrace) v1.0.1
#
# **3. Justification**
# []
#
# **4. Results**
# []
#
# **5. Notes**
# []
#
# **Inputs Files**
# | Name                           | Extension | File Size | Description                                                                                                                |
# | ------------------------------ | --------- | --------- | -------------------------------------------------------------------------------------------------------------------------- |
# | `[]` | .fastq.gz | `[]`  | Gzipped FASTQ file containing [RNA?] |
